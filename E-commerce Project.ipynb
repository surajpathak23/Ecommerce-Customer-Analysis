# %% [markdown]
# #TASK 1

# %% [markdown]
# Load the dataset

# %%
import pandas as pd
df=pd.read_csv('/content/ecommerce_customers_large.csv')
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male        118266             98        Edge
# 1          1002   57  Female         71930             39        Edge
# 2          1003   50  Female        113230             43       Opera
# 3          1004   50  Female         69083             15      Chrome
# 4          1005   50  Female        109557             52     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male         63875             40      Chrome
# 116        1117   58  Female         48760             43        Edge
# 117        1118   59  Female         76213             28       Opera
# 118        1119   48    Male         61526             15      Safari
# 119        1120   56  Female         68977             57        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType
# 0                    4                   31     Tablet
# 1                   12                   10     Mobile
# 2                   16                    9     Mobile
# 3                    1                   50     Mobile
# 4                   13                    4    Desktop
# ..                 ...                  ...        ...
# 115                  6                    2    Desktop
# 116                  6                    6     Tablet
# 117                 18                   38    Desktop
# 118                 14                    5    Desktop
# 119                  8                   47     Tablet
#
# [120 rows x 9 columns]

# %% [markdown]
# **Initial Exploration**

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0        1001   23    Male        118266             98        Edge
# 1        1002   57  Female         71930             39        Edge
# 2        1003   50  Female        113230             43       Opera
# 3        1004   50  Female         69083             15      Chrome
# 4        1005   50  Female        109557             52     Firefox
#
#    PurchaseFrequency  LastPurchaseDaysAgo DeviceType
# 0                  4                   31     Tablet
# 1                 12                   10     Mobile
# 2                 16                    9     Mobile
# 3                  1                   50     Mobile
# 4                 13                    4    Desktop

# %%
df.columns.tolist()
# Out:
# ['CustomerID',
#  'Age',
#  'Gender',
#  'AnnualIncome',
#  'SpendingScore',
#  'BrowserType',
#  'PurchaseFrequency',
#  'LastPurchaseDaysAgo',
#  'DeviceType']

# %% [markdown]
# **Dataset Shape & Memory Usage**

# %%
# Dataset Shape
print(f"Dataset contains {df.shape[0]} rows and {df.shape[1]} columns.")

# Memory usage
print("\nMemory Usage:")
print(df.info(memory_usage='deep'))
# Out:
# Dataset contains 120 rows and 9 columns.
#
# Memory Usage:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           120 non-null    int64
#  1   Age                  120 non-null    int64
#  2   Gender               120 non-null    object
#  3   AnnualIncome         120 non-null    int64
#  4   SpendingScore        120 non-null    int64
#  5   BrowserType          120 non-null    object
#  6   PurchaseFrequency    120 non-null    int64
#  7   LastPurchaseDaysAgo  120 non-null    int64
#  8   DeviceType           120 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 27.8 KB
# None

# %% [markdown]
# **Missing Values Analysis**

# %%
missing = df.isnull().sum()
missing = missing[missing > 0]
print(missing.to_frame('Missing Values').assign(Percentage=lambda x: (x['Missing Values'] / len(df) * 100).round(2)))
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %% [markdown]
# **Data Types Assessment**

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# CustomerID              int64
# Age                     int64
# Gender                 object
# AnnualIncome            int64
# SpendingScore           int64
# BrowserType            object
# PurchaseFrequency       int64
# LastPurchaseDaysAgo     int64
# DeviceType             object
# dtype: object

# %% [markdown]
# **Duplicate Records Count**

# %%
duplicates = df.duplicated().sum()
print(f"\nTotal duplicate records: {duplicates}")
# Out:
# Total duplicate records: 0

# %% [markdown]
# **Basic Statistical Summary**

# %%
print("\nBasic Statistical Summary (Numerical Columns):")
display(df.describe())
# Out:
# Basic Statistical Summary (Numerical Columns):
#         CustomerID        Age   AnnualIncome  SpendingScore  \
# count   120.000000  120.00000     120.000000     120.000000
# mean   1060.500000   42.67500   68623.966667      48.266667
# std      34.785054   13.20629   29992.299637      27.213360
# min    1001.000000   19.00000   20178.000000       1.000000
# 25%    1030.750000   31.75000   43615.500000      28.000000
# 50%    1060.500000   43.00000   67643.500000      48.000000
# 75%    1090.250000   52.25000   92256.250000      67.000000
# max    1120.000000   65.00000  119184.000000     100.000000
#
#        PurchaseFrequency  LastPurchaseDaysAgo
# count         120.000000           120.000000
# mean           10.466667            26.858333
# std             5.489384            18.204393
# min             1.000000             0.000000
# 25%             6.000000            10.000000
# 50%            11.000000            26.000000
# 75%            16.000000            43.000000
# max            20.000000            60.000000

# %% [markdown]
# **Document Data Quality Issues Check**

# %%
issues = []

if df.isnull().sum().sum(): issues.append("Missing values found.")
if df.duplicated().sum(): issues.append("Duplicate rows found.")

for col in df.select_dtypes('object'):
    if (df[col].dropna().str.strip() == '').any():
        issues.append(f"Blank values in '{col}'.")

print("\nIssues:" if issues else "\nNo data issues.")
for i, msg in enumerate(issues, 1):
    print(f"{i}. {msg}")
# Out:
# No data issues.

# %% [markdown]
# #TASK 2#

# %% [markdown]
# Handle Missing Values

# %%
# Drop columns with >50% missing
df.dropna(thresh=0.5*len(df), axis=1, inplace=True)

# Fill numeric with median, categorical with mode
df.fillna({**df.select_dtypes('number').median(),
           **df.select_dtypes('object').mode().iloc[0]}, inplace=True)

# %% [markdown]
# **Remove Duplicates**

# %%
df = df.drop_duplicates()

# %% [markdown]
# **Fix Data Types**

# %%
# Date conversion
df['order_date'] = pd.to_datetime(df.get('order_date'), errors='coerce')

# Convert object columns to numeric where possible
df = df.apply(lambda col: pd.to_numeric(col, errors='ignore') if col.dtype == 'object' else col)

# Convert remaining object columns to category
df[df.select_dtypes('object').columns] = df.select_dtypes('object').astype('category')
df
# Out:
# /tmp/ipython-input-188-2785735539.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(lambda col: pd.to_numeric(col, errors='ignore') if col.dtype == 'object' else col)
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male        118266             98        Edge
# 1          1002   57  Female         71930             39        Edge
# 2          1003   50  Female        113230             43       Opera
# 3          1004   50  Female         69083             15      Chrome
# 4          1005   50  Female        109557             52     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male         63875             40      Chrome
# 116        1117   58  Female         48760             43        Edge
# 117        1118   59  Female         76213             28       Opera
# 118        1119   48    Male         61526             15      Safari
# 119        1120   56  Female         68977             57        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType  order_date
# 0                    4                   31     Tablet         NaN
# 1                   12                   10     Mobile         NaN
# 2                   16                    9     Mobile         NaN
# 3                    1                   50     Mobile         NaN
# 4                   13                    4    Desktop         NaN
# ..                 ...                  ...        ...         ...
# 115                  6                    2    Desktop         NaN
# 116                  6                    6     Tablet         NaN
# 117                 18                   38    Desktop         NaN
# 118                 14                    5    Desktop         NaN
# 119                  8                   47     Tablet         NaN
#
# [120 rows x 10 columns]

# %%
# Fill NaT with a default date (example: Jan 1, 2020)
df['order_date'] = df['order_date'].fillna(pd.Timestamp("2020-01-01"))
df
# Out:
# /tmp/ipython-input-189-3345769889.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['order_date'] = df['order_date'].fillna(pd.Timestamp("2020-01-01"))
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male        118266             98        Edge
# 1          1002   57  Female         71930             39        Edge
# 2          1003   50  Female        113230             43       Opera
# 3          1004   50  Female         69083             15      Chrome
# 4          1005   50  Female        109557             52     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male         63875             40      Chrome
# 116        1117   58  Female         48760             43        Edge
# 117        1118   59  Female         76213             28       Opera
# 118        1119   48    Male         61526             15      Safari
# 119        1120   56  Female         68977             57        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
# [120 rows x 10 columns]

# %% [markdown]
# **Clean Text Data**

# %%
# Function to clean text
def clean_text(s):
    if isinstance(s, str):
        return s.strip().title()
    return s

# Apply to all object columns
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].apply(clean_text)

# Clean phone numbers & emails (example placeholders)
# df['phone'] = df['phone'].str.replace(r'\D', '', regex=True)
# df['email'] = df['email'].str.lower().str.strip()

# %%
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male        118266             98        Edge
# 1          1002   57  Female         71930             39        Edge
# 2          1003   50  Female        113230             43       Opera
# 3          1004   50  Female         69083             15      Chrome
# 4          1005   50  Female        109557             52     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male         63875             40      Chrome
# 116        1117   58  Female         48760             43        Edge
# 117        1118   59  Female         76213             28       Opera
# 118        1119   48    Male         61526             15      Safari
# 119        1120   56  Female         68977             57        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
# [120 rows x 10 columns]

# %% [markdown]
# #TASK 3

# %% [markdown]
# Outlier Detection and Treatment

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Select numerical columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
print("Numerical columns:", num_cols.tolist())
# Out:
# Numerical columns: ['CustomerID', 'Age', 'AnnualIncome', 'SpendingScore', 'PurchaseFrequency', 'LastPurchaseDaysAgo']

# %% [markdown]
# **Identify Outliers using IQR Method**

# %%
# IQR method
def detect_outliers_iqr(data, col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[col] < lower_bound) | (data[col] > upper_bound)]

# Example: Detect outliers in 'AnnualIncome'
outliers_income = detect_outliers_iqr(df, 'AnnualIncome')
print(f"Outliers in 'AnnualIncome': {len(outliers_income)} rows")
# Out:
# Outliers in 'AnnualIncome': 0 rows

# %% [markdown]
# **Identify Outliers using Z-Score Method**

# %%
# Z-score method
def detect_outliers_zscore(data, col, threshold=3):
    z_scores = stats.zscore(data[col])
    return data[(np.abs(z_scores) > threshold)]

# Example: Z-score outliers for 'SpendingScore'
outliers_spending = detect_outliers_zscore(df, 'SpendingScore')
print(f"Outliers in 'SpendingScore': {len(outliers_spending)} rows")
# Out:
# Outliers in 'SpendingScore': 0 rows

# %% [markdown]
# **Decide: Remove, Cap, or Keep Outliers**

# %%
# Cap function using IQR bounds
def cap_outliers_iqr(data, col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    data[col] = np.where(data[col] < lower, lower, data[col])
    data[col] = np.where(data[col] > upper, upper, data[col])
    return data

# Apply capping to selected columns
for col in ['AnnualIncome', 'SpendingScore']:
    df = cap_outliers_iqr(df, col)
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male      118266.0           98.0        Edge
# 1          1002   57  Female       71930.0           39.0        Edge
# 2          1003   50  Female      113230.0           43.0       Opera
# 3          1004   50  Female       69083.0           15.0      Chrome
# 4          1005   50  Female      109557.0           52.0     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male       63875.0           40.0      Chrome
# 116        1117   58  Female       48760.0           43.0        Edge
# 117        1118   59  Female       76213.0           28.0       Opera
# 118        1119   48    Male       61526.0           15.0      Safari
# 119        1120   56  Female       68977.0           57.0        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
# [120 rows x 10 columns]

# %%
# Remove rows with extreme income outliers
df = df[~df.index.isin(outliers_income.index)]

# %% [markdown]
# **Document Decisions (Business Justification - example)**

# %%
print("\n📌 Business Justification:")
print("""
1. We capped extreme values in 'AnnualIncome' and 'SpendingScore' to reduce the influence of outliers on analysis.
2. Capping is preferred over removal to retain customer data and avoid information loss.
3. Z-score helped double-check extreme cases; however, we used IQR for final treatment due to its robustness.
""")
# Out:
# 📌 Business Justification:
#
# 1. We capped extreme values in 'AnnualIncome' and 'SpendingScore' to reduce the influence of outliers on analysis.
# 2. Capping is preferred over removal to retain customer data and avoid information loss.
# 3. Z-score helped double-check extreme cases; however, we used IQR for final treatment due to its robustness.

# %% [markdown]
# #TASK 4

# %% [markdown]
# Feature Engineering Code

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# **Customer Tenure (days since registration)**

# %%
# Create fake registration_date for demo (if not available)
import numpy as np
df['registration_date'] = pd.to_datetime(np.random.choice(pd.date_range(start='2018-01-01', end='2022-01-01'), size=len(df)))

# Calculate customer tenure
today = pd.to_datetime("2025-01-01")  # or use datetime.today()
df['CustomerTenure'] = (today - df['registration_date']).dt.days
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male      118266.0           98.0        Edge
# 1          1002   57  Female       71930.0           39.0        Edge
# 2          1003   50  Female      113230.0           43.0       Opera
# 3          1004   50  Female       69083.0           15.0      Chrome
# 4          1005   50  Female      109557.0           52.0     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male       63875.0           40.0      Chrome
# 116        1117   58  Female       48760.0           43.0        Edge
# 117        1118   59  Female       76213.0           28.0       Opera
# 118        1119   48    Male       61526.0           15.0      Safari
# 119        1120   56  Female       68977.0           57.0        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date  \
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
#     registration_date  CustomerTenure
# 0          2020-06-04            1672
# 1          2020-11-06            1517
# 2          2021-12-18            1110
# 3          2021-03-22            1381
# 4          2020-08-07            1608
# ..                ...             ...
# 115        2021-06-25            1286
# 116        2020-01-17            1811
# 117        2020-02-21            1776
# 118        2018-04-10            2458
# 119        2019-12-17            1842
#
# [120 rows x 12 columns]

# %% [markdown]
# **Average Order Value**

# %%
# Create dummy total purchase amount if not available
df['TotalPurchaseAmount'] = df['SpendingScore'] * df['PurchaseFrequency'] * 10

# Calculate average order value
df['AvgOrderValue'] = df['TotalPurchaseAmount'] / df['PurchaseFrequency']
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male      118266.0           98.0        Edge
# 1          1002   57  Female       71930.0           39.0        Edge
# 2          1003   50  Female      113230.0           43.0       Opera
# 3          1004   50  Female       69083.0           15.0      Chrome
# 4          1005   50  Female      109557.0           52.0     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male       63875.0           40.0      Chrome
# 116        1117   58  Female       48760.0           43.0        Edge
# 117        1118   59  Female       76213.0           28.0       Opera
# 118        1119   48    Male       61526.0           15.0      Safari
# 119        1120   56  Female       68977.0           57.0        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date  \
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
#     registration_date  CustomerTenure  TotalPurchaseAmount  AvgOrderValue
# 0          2020-06-04            1672               3920.0          980.0
# 1          2020-11-06            1517               4680.0          390.0
# 2          2021-12-18            1110               6880.0          430.0
# 3          2021-03-22            1381                150.0          150.0
# 4          2020-08-07            1608               6760.0          520.0
# ..                ...             ...                  ...            ...
# 115        2021-06-25            1286               2400.0          400.0
# 116        2020-01-17            1811               2580.0          430.0
# 117        2020-02-21            1776               5040.0          280.0
# 118        2018-04-10            2458               2100.0          150.0
# 119        2019-12-17            1842               4560.0          570.0
#
# [120 rows x 14 columns]

# %% [markdown]
# **Days Since Last Order**

# %%
df['DaysSinceLastOrder'] = df['LastPurchaseDaysAgo']  # Already exists
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male      118266.0           98.0        Edge
# 1          1002   57  Female       71930.0           39.0        Edge
# 2          1003   50  Female      113230.0           43.0       Opera
# 3          1004   50  Female       69083.0           15.0      Chrome
# 4          1005   50  Female      109557.0           52.0     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male       63875.0           40.0      Chrome
# 116        1117   58  Female       48760.0           43.0        Edge
# 117        1118   59  Female       76213.0           28.0       Opera
# 118        1119   48    Male       61526.0           15.0      Safari
# 119        1120   56  Female       68977.0           57.0        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date  \
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
#     registration_date  CustomerTenure  TotalPurchaseAmount  AvgOrderValue  \
# 0          2020-06-04            1672               3920.0          980.0
# 1          2020-11-06            1517               4680.0          390.0
# 2          2021-12-18            1110               6880.0          430.0
# 3          2021-03-22            1381                150.0          150.0
# 4          2020-08-07            1608               6760.0          520.0
# ..                ...             ...                  ...            ...
# 115        2021-06-25            1286               2400.0          400.0
# 116        2020-01-17            1811               2580.0          430.0
# 117        2020-02-21            1776               5040.0          280.0
# 118        2018-04-10            2458               2100.0          150.0
# 119        2019-12-17            1842               4560.0          570.0
#
#      DaysSinceLastOrder
# 0                    31
# 1                    10
# 2                     9
# 3                    50
# 4                     4
# ..                  ...
# 115                   2
# 116                   6
# 117                  38
# 118                   5
# 119                  47
#
# [120 rows x 15 columns]

# %% [markdown]
# **Age Groups**

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 25, 40, 60, 100],
                        labels=['Youth', 'Young Adult', 'Adult', 'Senior'])
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male      118266.0           98.0        Edge
# 1          1002   57  Female       71930.0           39.0        Edge
# 2          1003   50  Female      113230.0           43.0       Opera
# 3          1004   50  Female       69083.0           15.0      Chrome
# 4          1005   50  Female      109557.0           52.0     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male       63875.0           40.0      Chrome
# 116        1117   58  Female       48760.0           43.0        Edge
# 117        1118   59  Female       76213.0           28.0       Opera
# 118        1119   48    Male       61526.0           15.0      Safari
# 119        1120   56  Female       68977.0           57.0        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date  \
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
#     registration_date  CustomerTenure  TotalPurchaseAmount  AvgOrderValue  \
# 0          2020-06-04            1672               3920.0          980.0
# 1          2020-11-06            1517               4680.0          390.0
# 2          2021-12-18            1110               6880.0          430.0
# 3          2021-03-22            1381                150.0          150.0
# 4          2020-08-07            1608               6760.0          520.0
# ..                ...             ...                  ...            ...
# 115        2021-06-25            1286               2400.0          400.0
# 116        2020-01-17            1811               2580.0          430.0
# 117        2020-02-21            1776               5040.0          280.0
# 118        2018-04-10            2458               2100.0          150.0
# 119        2019-12-17            1842               4560.0          570.0
#
#      DaysSinceLastOrder AgeGroup
# 0                    31    Youth
# 1                    10    Adult
# 2                     9    Adult
# 3                    50    Adult
# 4                     4    Adult
# ..                  ...      ...
# 115                   2    Adult
# 116                   6    Adult
# 117                  38    Adult
# 118                   5    Adult
# 119                  47    Adult
#
# [120 rows x 16 columns]

# %% [markdown]
# **Income Brackets**

# %%
df['IncomeBracket'] = pd.cut(df['AnnualIncome'],
                             bins=[0, 40000, 80000, 120000, np.inf],
                             labels=['Low', 'Mid', 'High', 'Very High'])
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male      118266.0           98.0        Edge
# 1          1002   57  Female       71930.0           39.0        Edge
# 2          1003   50  Female      113230.0           43.0       Opera
# 3          1004   50  Female       69083.0           15.0      Chrome
# 4          1005   50  Female      109557.0           52.0     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male       63875.0           40.0      Chrome
# 116        1117   58  Female       48760.0           43.0        Edge
# 117        1118   59  Female       76213.0           28.0       Opera
# 118        1119   48    Male       61526.0           15.0      Safari
# 119        1120   56  Female       68977.0           57.0        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date  \
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
#     registration_date  CustomerTenure  TotalPurchaseAmount  AvgOrderValue  \
# 0          2020-06-04            1672               3920.0          980.0
# 1          2020-11-06            1517               4680.0          390.0
# 2          2021-12-18            1110               6880.0          430.0
# 3          2021-03-22            1381                150.0          150.0
# 4          2020-08-07            1608               6760.0          520.0
# ..                ...             ...                  ...            ...
# 115        2021-06-25            1286               2400.0          400.0
# 116        2020-01-17            1811               2580.0          430.0
# 117        2020-02-21            1776               5040.0          280.0
# 118        2018-04-10            2458               2100.0          150.0
# 119        2019-12-17            1842               4560.0          570.0
#
#      DaysSinceLastOrder AgeGroup IncomeBracket
# 0                    31    Youth          High
# 1                    10    Adult           Mid
# 2                     9    Adult          High
# 3                    50    Adult           Mid
# 4                     4    Adult          High
# ..                  ...      ...           ...
# 115                   2    Adult           Mid
# 116                   6    Adult           Mid
# 117                  38    Adult           Mid
# 118                   5    Adult           Mid
# 119                  47    Adult           Mid
#
# [120 rows x 17 columns]

# %% [markdown]
# **Spending Categories**

# %%
df['SpendingCategory'] = pd.cut(df['SpendingScore'],
                                bins=[0, 30, 70, 100],
                                labels=['Low Spender', 'Medium Spender', 'High Spender'])
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male      118266.0           98.0        Edge
# 1          1002   57  Female       71930.0           39.0        Edge
# 2          1003   50  Female      113230.0           43.0       Opera
# 3          1004   50  Female       69083.0           15.0      Chrome
# 4          1005   50  Female      109557.0           52.0     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male       63875.0           40.0      Chrome
# 116        1117   58  Female       48760.0           43.0        Edge
# 117        1118   59  Female       76213.0           28.0       Opera
# 118        1119   48    Male       61526.0           15.0      Safari
# 119        1120   56  Female       68977.0           57.0        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date  \
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
#     registration_date  CustomerTenure  TotalPurchaseAmount  AvgOrderValue  \
# 0          2020-06-04            1672               3920.0          980.0
# 1          2020-11-06            1517               4680.0          390.0
# 2          2021-12-18            1110               6880.0          430.0
# 3          2021-03-22            1381                150.0          150.0
# 4          2020-08-07            1608               6760.0          520.0
# ..                ...             ...                  ...            ...
# 115        2021-06-25            1286               2400.0          400.0
# 116        2020-01-17            1811               2580.0          430.0
# 117        2020-02-21            1776               5040.0          280.0
# 118        2018-04-10            2458               2100.0          150.0
# 119        2019-12-17            1842               4560.0          570.0
#
#      DaysSinceLastOrder AgeGroup IncomeBracket SpendingCategory
# 0                    31    Youth          High     High Spender
# 1                    10    Adult           Mid   Medium Spender
# 2                     9    Adult          High   Medium Spender
# 3                    50    Adult           Mid      Low Spender
# 4                     4    Adult          High   Medium Spender
# ..                  ...      ...           ...              ...
# 115                   2    Adult           Mid   Medium Spender
# 116                   6    Adult           Mid   Medium Spender
# 117                  38    Adult           Mid      Low Spender
# 118                   5    Adult           Mid      Low Spender
# 119                  47    Adult           Mid   Medium Spender
#
# [120 rows x 18 columns]

# %% [markdown]
# **Optional: Interaction Feature (Example)**

# %%
# Income x SpendingScore (just an example interaction)
df['Income_Score'] = df['AnnualIncome'] * df['SpendingScore']
df
# Out:
#      CustomerID  Age  Gender  AnnualIncome  SpendingScore BrowserType  \
# 0          1001   23    Male      118266.0           98.0        Edge
# 1          1002   57  Female       71930.0           39.0        Edge
# 2          1003   50  Female      113230.0           43.0       Opera
# 3          1004   50  Female       69083.0           15.0      Chrome
# 4          1005   50  Female      109557.0           52.0     Firefox
# ..          ...  ...     ...           ...            ...         ...
# 115        1116   43    Male       63875.0           40.0      Chrome
# 116        1117   58  Female       48760.0           43.0        Edge
# 117        1118   59  Female       76213.0           28.0       Opera
# 118        1119   48    Male       61526.0           15.0      Safari
# 119        1120   56  Female       68977.0           57.0        Edge
#
#      PurchaseFrequency  LastPurchaseDaysAgo DeviceType order_date  \
# 0                    4                   31     Tablet 2020-01-01
# 1                   12                   10     Mobile 2020-01-01
# 2                   16                    9     Mobile 2020-01-01
# 3                    1                   50     Mobile 2020-01-01
# 4                   13                    4    Desktop 2020-01-01
# ..                 ...                  ...        ...        ...
# 115                  6                    2    Desktop 2020-01-01
# 116                  6                    6     Tablet 2020-01-01
# 117                 18                   38    Desktop 2020-01-01
# 118                 14                    5    Desktop 2020-01-01
# 119                  8                   47     Tablet 2020-01-01
#
#     registration_date  CustomerTenure  TotalPurchaseAmount  AvgOrderValue  \
# 0          2020-06-04            1672               3920.0          980.0
# 1          2020-11-06            1517               4680.0          390.0
# 2          2021-12-18            1110               6880.0          430.0
# 3          2021-03-22            1381                150.0          150.0
# 4          2020-08-07            1608               6760.0          520.0
# ..                ...             ...                  ...            ...
# 115        2021-06-25            1286               2400.0          400.0
# 116        2020-01-17            1811               2580.0          430.0
# 117        2020-02-21            1776               5040.0          280.0
# 118        2018-04-10            2458               2100.0          150.0
# 119        2019-12-17            1842               4560.0          570.0
#
#      DaysSinceLastOrder AgeGroup IncomeBracket SpendingCategory  Income_Score
# 0                    31    Youth          High     High Spender    11590068.0
# 1                    10    Adult           Mid   Medium Spender     2805270.0
# 2                     9    Adult          High   Medium Spender     4868890.0
# 3                    50    Adult           Mid      Low Spender     1036245.0
# 4                     4    Adult          High   Medium Spender     5696964.0
# ..                  ...      ...           ...              ...           ...
# 115                   2    Adult           Mid   Medium Spender     2555000.0
# 116                   6    Adult           Mid   Medium Spender     2096680.0
# 117                  38    Adult           Mid      Low Spender     2133964.0
# 118                   5    Adult           Mid      Low Spender      922890.0
# 119                  47    Adult           Mid   Medium Spender     3931689.0
#
# [120 rows x 19 columns]

# %% [markdown]
# **Data Check**

# %%
df[['CustomerTenure', 'AvgOrderValue', 'DaysSinceLastOrder', 'AgeGroup',
    'IncomeBracket', 'SpendingCategory', 'Income_Score']].head()
# Out:
#    CustomerTenure  AvgOrderValue  DaysSinceLastOrder AgeGroup IncomeBracket  \
# 0            1672          980.0                  31    Youth          High
# 1            1517          390.0                  10    Adult           Mid
# 2            1110          430.0                   9    Adult          High
# 3            1381          150.0                  50    Adult           Mid
# 4            1608          520.0                   4    Adult          High
#
#   SpendingCategory  Income_Score
# 0     High Spender    11590068.0
# 1   Medium Spender     2805270.0
# 2   Medium Spender     4868890.0
# 3      Low Spender     1036245.0
# 4   Medium Spender     5696964.0
